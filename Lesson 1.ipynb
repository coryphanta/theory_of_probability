# %% [markdown]
# ### Задача 1
#
# Группа студентов изучает 10 различных дисциплин. Сколькими способами можно составить расписание на понедельник, если в этот день должно быть 4 разных занятия?

# %% [markdown]
# <br>
# $\frac{10!}{4!(10 - 4)!} = \frac{10!}{4!\cdot6!} = \frac{6!\cdot7\cdot8\cdot9\cdot10}{4!\cdot6!} = \frac{5040}{24} = 210$

# %% [markdown]
# ### Задача 2
#
# Из колоды в 52 карты вынимают случайным образом 4 карты. Найти число исходов, соответствующих тому, что был вытянут хотя бы один туз.

# %% [markdown]
# Пользуемся формулой
# <br>
# $P(A)=1−P(\bar{A})$
# <br>
# $𝑃(\bar{𝐴})$  - нет ни одного туза

# %% [markdown]
# Найдем $P(bar{A})$ сначала
# <br>
# $n = C_{52}^4 = 270725$
# <br>
# 52 карты всего - тузы = 48
# <br>
# $m = C_{48}^4 = 194580$
# <br>
# $P(\bar{A}) = \frac{194580}{270725} = \approx 0,72$

# %% [markdown]
# Тогда $P(A) = 1 - 0,72 = 0,28$

# %% [markdown]
# ### Задача 3
#
# Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что два определённых человека будут сидеть рядом?
#
# Всего способов рассадки - 7!
# <br>
# У нас пара. Они относительно друг друга могут сесть двумся способами: 1,2 или 2,1, получаем 2! способа рассадки для них, всего 6 счучаев, когда таким образом можно перемешаться: 1 c 2| 1 c 3| 1 c 4| 1 c 5| 1 c 6| 1 c 7 скамейка кончилась
# <br>
# У остальных остается 5! способов рассадки
#
# Используем формулу $𝑃(𝐴)=\frac{𝑚}{𝑛}$
# <br>
# $P = \frac{5! \cdot 2! \cdot 6}{7!} = \frac{2}{7} \approx 2,9$

# %% [markdown]
# Задача 4
#
# Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?
#
# a) Считаем вероятность общую
# <br>
# Ищем n как сочетание:
# <br>
# $n = \frac{60!}{3! \cdot 57!} = 34220$
# <br>
# Так же ищем m
# <br>
# $m = \frac{50!}{3! \cdot 47!} = 19600$
# <br>
# $P = \frac{\frac{60!}{3! \cdot 57!}}{\frac{50!}{3! \cdot 47!}} = \frac{60!}{3! \cdot 57!} \cdot \frac{3! \cdot 47!}{50!} = \frac{60!\cdot3! \cdot 47!}{3! \cdot 57! \cdot 50!} = \frac{205320}{117600}$
# <br>
# Кажется я перепутала m и n этажами, переписывать не буду, просто переверну результат
# $\frac{205320}{117600} \downarrow \uparrow \frac{117600}{205320} \approx 0,57$

# %% [markdown]
# b) Считаем m для случая с двумя вопросами
# $m = \frac{50!}{2! \cdot 48!}$
# <br>
# n уже рассчитали, найдем P
# <br>
# $P = \frac{\frac{50!}{2! \cdot 48!}}{\frac{60!}{3! \cdot 57!}} = \frac{50!\cdot3! \cdot 57!}{2! \cdot 48! \cdot 60!} = \frac{14700}{410640} \approx 0,036 \cdot 10 (билетов.не.выучено) \approx 0,36$

# %% [markdown]
# Задача 5
#
# Бросается игральная кость. Пусть событие A - появление чётного числа, событие B - появление числа больше трёх. Являются ли эти события независимыми?
# <br>
# Ответ: Да, события незвисимые. Событие А никак не влияет на событие B

# %% [markdown]
# Задача 6 (Дополнительно)
#
# Допустим, имеется некоторая очень редкая болезнь (поражает 0.1 % населения). Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным. Врач говорит вам, что этот тест верно выявляет 99 % больных этой болезнью и всего лишь в 1 % случаев даёт ложный положительный ответ.
#
# Вопрос: какова вероятность, что вы действительно больны ей?
#
# Подсказка: вновь используйте формулу Байеса с раскрытием знаменателя с помощью формулы полной вероятности.
